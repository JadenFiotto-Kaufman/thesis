# %%
from baukit import PaintWidget, show

pw = PaintWidget(src='cos.png')

show(pw)
# Out:
# <style>
# #_140393908488656_1 { position: relative; display: inline-block; }
# #_140393908488656_1 .paintmask {
# position: absolute; top:0; left: 0; z-index: 1;
# opacity: 0.7 }
# #_140393908488656_1 .paintmask.vanishing {
# opacity: 0; transition: opacity .1s ease-in-out; }
# #_140393908488656_1 .paintmask.vanishing:hover { opacity: 0.7; }
# </style><div id="_140393908488656_1" style="display:flex;flex:1;flex-flow:column;gap:3px"></div><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# ...

# %%
pw
# Out:
# <style>
# #_140393908488656_2 { position: relative; display: inline-block; }
# #_140393908488656_2 .paintmask {
# position: absolute; top:0; left: 0; z-index: 1;
# opacity: 0.7 }
# #_140393908488656_2 .paintmask.vanishing {
# opacity: 0; transition: opacity .1s ease-in-out; }
# #_140393908488656_2 .paintmask.vanishing:hover { opacity: 0.7; }
# </style><div id="_140393908488656_2" style="display:flex;flex:1;flex-flow:column;gap:3px"></div><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# ...
